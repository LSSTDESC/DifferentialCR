# %%
import numpy as np
import astropy.units as u
import matplotlib.pyplot as plt
import galsim
import os
from astropy.table import Table

from astropy.modeling.models import BlackBody

from utils import BB, apply_filter, apply_DCR, weighted_avg_and_std

from scipy.interpolate import interp1d


def apply_filter(wvl, data, band = 'g', rm_leakage = True):
    '''
    wvl - a list of the wavelengths in nm
    data - a N x M list of SEDs, N = number of SEDs, M = len of wvl
    returns data with the band filter applied to each SEDwvl
    '''
    
    filter_file = f'filter_files/noleak_{band}.dat'
    filter_band = np.loadtxt(filter_file).T #filter_band[0] -> wavelengths, filter_band[1] -> filter pass fraction

    # remove filter leakage: set lower bound of filter to 0.001 throughput
    if rm_leakage:
        leakage_mask = filter_band[1] < 0.001
        filter_band[1][leakage_mask] = np.zeros(np.sum(leakage_mask))
    
    func = interp1d(filter_band[0], filter_band[1])
    SED_filter = func(wvl)
    
    return data * SED_filter


def synth_fnu(wl, Flam, band, wl_units = 'nm'):
    '''
    Calculates a synthetic flux
    wl - wavelength array in apropriate units (see wl_units)
    Flam - SED (unfiltered) in in erg/cm^2/s/A
    wl_units - 'nm' or 'A'
    '''

    h  = 6.62607015e-27       # erg s
    c  = 2.99792458e18        # Å / s
    hc = h * c                # erg Å  (≈ 1.986e-8)

    
    if wl_units == 'nm':
        wl_A = wl * 10
        wl_nm = wl
    elif wl_units == 'A':
        wl_A = wl
        wl_nm = wl/10

    filter_file = f'filter_files/total_{band}.dat'
    filter_band = np.loadtxt(filter_file).T #filter_band[0] -> wavelengths, filter_band[1] -> filter pass fraction

    T = interp1d(filter_band[0], filter_band[1])(wl_nm)

    num = np.trapezoid(Flam * T * wl_A, wl_A)
    den = np.trapezoid(T / wl_A, wl_A)

    phot_flux = 1/hc * np.trapezoid(Flam*T*wl_A, wl_A)
    
    return phot_flux # num/ den   # proportional to <f_nu>

h  = 6.62607015e-27       # erg s
c  = 2.99792458e18        # Å / s
hc = h * c                # erg Å  (≈ 1.986e-8)

# %%
zenith = 45 #degrees
# dwvl = 0.1 #wavelength step
# wavelengths = np.arange(290, 1160, dwvl) 

#Matthew's atmospheric conditions
pressure=70.0,  # kPa
temperature=293.15,  # K
H2O_pressure=0.0,

#Pat and Josh's paper atmospheric conditions 
pressure=69.328
temperature=293.15
H2O_pressure=1.067

wvl = np.linspace(300, 1150, 8500)
flat = np.ones(len(wvl))
BB5000 = BB(wvl, 5000, 1e-6)


flat_filtered = {}
BB_filtered = {}

colors = {'u' : 'purple', 'g':'blue', 'r': 'green', 'i': 'orange', 'z' : 'magenta', 'y' : 'red'}


# plt.plot(wvl, BB5000, 'k', label = f'BB 5000')

for band in 'ugrizy':
    flat_filtered[band] = apply_filter(wvl, flat, band, rm_leakage = False) * wvl * 10/hc
    BB_filtered[band] = apply_filter(wvl, BB5000, band, rm_leakage = False) * wvl * 10/hc
    
    plt.plot(wvl, flat_filtered[band], ls = '-', color = colors[band], alpha = 0.5)
    # plt.plot(wvl, BB_filtered[band], ls = '-', color = colors[band])
plt.ylabel('Photon density')
# Out:
# Text(0, 0.5, 'Photon density')

# %%
from utils import mean_and_std
# def mean_and_std(x_array, weights_dict, param_array = [None], multi = False):
#     if param_array[0] == None:
#         param_array = x_array
    
#     x_transpose = np.array(param_array).T #create a vertical array for purposes of matrix multiplication below

#     means = {}
#     stdevs = {}

#     if multi:
#         for band, weights in weights_dict.items():
#             mean = np.trapezoid(x_array, weights * x_transpose, axis = 1)/np.trapezoid(x_array, weights, axis =1)
#             means[band] = mean
#             stdevs[band] = np.sqrt(np.trapezoid(x_array, weights * (x_transpose - mean[:, np.newaxis])**2, axis=1) / np.trapezoid(x_array, weights, axis=1))

#             # print(f'{band} (average): mean = {np.round(np.mean(mean), 4)}, stdev = {np.round(np.mean(stdevs[band]), 4)}')
#     else:
#         for band, weights in weights_dict.items():
#             mean = np.trapezoid(x_array, weights * x_transpose)/np.trapezoid(x_array, weights)
#             means[band] = mean
#             stdevs[band] = np.sqrt(np.trapezoid(x_array, weights * (x_transpose - mean)**2) / np.trapezoid(x_array, weights))
        

#     return means, stdevs
    

flat_refraction_angles, flat_filtered_refracted = apply_DCR(wvl, flat_filtered, zenith, pressure, temperature, H2O_pressure)
BB_refraction_angles, BB_filtered_refracted = apply_DCR(wvl, BB_filtered , zenith, pressure, temperature, H2O_pressure)

flat_means, flat_stdevs = mean_and_std(flat_refraction_angles, flat_filtered_refracted, multi = False)
BB_means, BB_stdevs = mean_and_std(BB_refraction_angles, BB_filtered_refracted, multi = False)

print('Integral over R')
for band in 'g':
    print(band)
    print(BB_means[band])
    print((BB_stdevs[band]**2))


flat_means, flat_stdevs = mean_and_std(wvl, flat_filtered, param_array = flat_refraction_angles, multi = False)
BB_means, BB_stdevs = mean_and_std(wvl, BB_filtered, param_array = BB_refraction_angles, multi = False)

print('Integral over lamdba')
for band in 'g':
    print(band)
    print(BB_means[band])
    print((BB_stdevs[band]**2))

    
# flat_means, flat_stdevs = weighted_avg_and_std(flat_refraction_angles, flat_filtered_refracted, multi = False)
# BB_means, BB_stdevs = weighted_avg_and_std(BB_refraction_angles, BB_filtered_refracted, multi = False)

# print('Sum over R')
# for band in 'g':
#     print(band)
#     print(BB_means[band])
#     print((BB_stdevs[band]**2))


    
for band in 'ugrizy':
    plt.plot(BB_refraction_angles, BB_filtered_refracted[band])
# Out:
# Integral over R
# g
# 38.65473424867062
# 0.032172889423240286
# Integral over lamdba
# g
# 38.65473424928931
# 0.03217288949024294

# %%
# define filters and SEDs in galsim

from galsim import degrees
# read in the LSST filters

datapath = galsim.meta_data.share_dir
filter_names = 'ugrizy'
filters = {}
for filter_name in filter_names:
    # filter_filename = os.path.join(datapath, 'bandpasses/LSST_{0}.dat'.format(filter_name))
    filter_filename = f'filter_files/noleak_{filter_name}.dat'
    # Here we create some galsim.Bandpass objects to represent the filters we're observing
    # through.  These include the entire imaging system throughput including the atmosphere,
    # reflective and refractive optics, filters, and the CCD quantum efficiency.  These are
    # also conveniently read in from two-column ASCII files where the first column is
    # wavelength and the second column is dimensionless throughput. The example filter files
    # units of nanometers for the wavelength type, so we specify that using the required
    # `wave_type` argument.
    filters[filter_name] = galsim.Bandpass(filter_filename, wave_type='nm')
    # For speed, we can thin out the wavelength sampling of the filter a bit.
    # In the following line, `rel_err` specifies the relative error when integrating over just
    # the filter (however, this is not necessarily the relative error when integrating over the
    # filter times an SED).
    filters[filter_name] = filters[filter_name].thin(rel_err=1e-4)
    # plt.plot(filters[filter_name].wave_list, filters[filter_name].__call__(filters[filter_name].wave_list))


table = galsim.LookupTable(wvl*10, BB5000 * 10 * wvl/hc, interpolant='linear')
sed = galsim.SED(table, wave_type='Ang', flux_type='fphotons')


table_flat = galsim.LookupTable(wvl*10, flat * 10 * wvl/hc, interpolant='linear')
sed_flat = galsim.SED(table_flat, wave_type='Ang', flux_type='fphotons')

# band = 'u'
# plt.plot(np.linspace(320, 1000, 1000), sed._mul_bandpass(filters[band])._call_fast(np.linspace(320, 1000, 1000))/np.max(sed._mul_bandpass(filters[band])._call_fast(np.linspace(320, 1000, 1000))), color = 'r')
# plt.plot(wvl, BB_filtered[band]/np.max(BB_filtered[band]), '.', color = colors[band])

# %%
R = galsim.dcr.get_refraction(wvl, zenith_angle = 45 * galsim.degrees)

from scipy.integrate import simpson
band = 'u'

flux = synth_fnu(wvl * 10, flat, band, wl_units = 'A')#simpson(x = wvl * 10, y = flat_filtered[band])
mean = simpson(x = wvl * 10, y = flat_filtered[band] * R) / flux
var = simpson(x = wvl * 10, y = flat_filtered[band] * (R - mean)**2) #/ flux
print(flux)
print(mean * (180 * 3600 / np.pi))
print(var * (180 * 3600 / np.pi)**2)
# Out:
# 14631865670592.754
# 39.04105125847634
# 1892171711263.201

# %%
Rs = {}
Vs = {}
Rs_flat = {}
Vs_flat = {}

for band in 'ugrizy':
        
    bandpass = filters[band] #galsim.Bandpass('LSST_r.dat', wave_type='nm')
    
    # DCR shifts for an object 30 deg from zenith, parallactic angle 0
    R, V = sed.calculateDCRMomentShifts(
        bandpass,
        zenith_angle=45 * galsim.degrees,
        parallactic_angle=0 * galsim.degrees,
    )
    
    # print("First-moment shift (arcsec):", R * 180 * 3600 / np.pi)
    # print("Second-moment shift matrix (arcsec^2):\n", V * (180 * 3600 / np.pi)**2)

                     
    R_flat, V_flat = sed_flat.calculateDCRMomentShifts(
        bandpass,
        zenith_angle = 45 * galsim.degrees,
        parallactic_angle = 0 * galsim.degrees,
    )

    Rs[band] = R * 180 * 3600 / np.pi
    Vs[band] = V * (180 * 3600 / np.pi)**2
    Rs_flat[band] = R_flat * 180 * 3600 / np.pi
    Vs_flat[band] = V_flat * (180 * 3600 / np.pi)**2
    
    # print("First-moment shift (arcsec):", R * 180 * 3600 / np.pi)
    # print("Second-moment shift matrix (arcsec^2):\n", V * (180 * 3600 / np.pi)**2)
    
    # print("Delta First-moment shift (arcsec):", (R_flat - R) * 180 * 3600 / np.pi)
    # print("Delta Second-moment shift matrix (arcsec^2):\n", (V_flat - V) * (180 * 3600 / np.pi)**2)

# %%
for band in 'ugrizy':
    print(band)
    print('Mean: ', BB_means[band]/ Rs[band][-1])
    print('Var: ', BB_stdevs[band]**2/ Vs[band][-1, -1])
    # print(BB_means[band])
    # print((BB_stdevs[band]**2))
# Out:
# u
# Mean:  0.9999997981200436
# Var:  0.9999415498507409
# g
# Mean:  1.0000000118408432
# Var:  0.9999696240764214
# r
# Mean:  1.0000000127622568
# Var:  1.0000032109978634
# i
# Mean:  0.999999991335681
# Var:  0.9999751105253872
# z
# Mean:  1.0000000086172445
# Var:  0.999967385088502
# y
# Mean:  1.000000015462252
# Var:  0.9999370750619331

# %%
# PSF

from galsim import Gaussian

psf_sigma = 1.     # arcsec
pixel_scale = 0.2  # arcsec / pixel
noise = 30.        # standard deviation of the counts in each pixel

psf = Gaussian(flux = 1, sigma = psf_sigma)

# %%
for band in 'ugrizy':
    filter_file = f'filter_files/total_{band}.dat'
    filter_band = np.loadtxt(filter_file).T 

    leakage_mask = filter_band[1] < 0.002
    filter_band[1][leakage_mask] = np.zeros(np.sum(leakage_mask))

    np.savetxt(f'filter_files/noleak_{band}.dat', filter_band.T)

    plt.plot(filter_band[0], filter_band[1])

plt.yscale('log')

# %%
zenith = 45
Trange = np.linspace(273.15 + 10, 273.5 + 30, 100)
Prange = np.linspace(60, 110, 100)
wavelength = 500 #nm

R_map = []
for pressure in Prange:
    R_map.append(galsim.dcr.get_refraction(wavelength, zenith_angle = zenith * galsim.degrees, temperature = Trange, pressure = pressure) * 180 * 3600 / np.pi)

fig, ax = plt.subplots()
pcm = ax.pcolormesh(Trange - 273.15, Prange, R_map, cmap = 'viridis', alpha = 0.9)
cont = ax.contour(Trange - 273.15, Prange, R_map, levels = [40, 50, 60],  colors = 'k')



dashed_contours = [32, 34, 36, 38, 42, 44, 46, 48, 52, 54, 56, 58, 62, 64]
cont2 = ax.contour(Trange - 273.15, Prange, R_map, levels = dashed_contours, colors = 'k', linestyles = 'dashed', linewidths = 0.5)

ax.clabel(cont, fontsize = 10)

fig.colorbar(pcm, label = r'Total Refraction (arcsec) ')
# im = ax.imshow(R_map)

ax.set_ylabel('Pressure (kPa)')
ax.set_xlabel(r'Temperature ($^\circ$C)')
ax.set_title(r'Chromatic Refraction ($\lambda = 500$ nm, $Z = 45^\circ$) ')
# Out:
# Text(0.5, 1.0, 'Chromatic Refraction ($\\lambda = 500$ nm, $Z = 45^\\circ$) ')

# %%
def weighted_avg_and_std(x_array, weights_dict, multi = False):

    """
    Return the weighted average and standard deviation.

    values, weights -- Numpy ndarrays with the same shape.
    """
    x_transpose = np.array(x_array).T #create a vertical array for purposes of matrix multiplication below

    means = {}
    stdevs = {}

    if multi:
        for band, weights in weights_dict.items():
            mean = np.sum(weights * x_transpose, axis = 1)/np.sum(weights, axis =1)
            means[band] = mean
            stdevs[band] = np.sqrt(np.sum(weights * (x_transpose - mean[:, np.newaxis])**2, axis=1) / np.sum(weights, axis=1))

            # print(f'{band} (average): mean = {np.round(np.mean(mean), 4)}, stdev = {np.round(np.mean(stdevs[band]), 4)}')
    else:
        for band, weights in weights_dict.items():
            mean = np.sum(weights * x_transpose)/np.sum(weights)
            means[band] = mean
            stdevs[band] = np.sqrt(np.sum(weights * (x_transpose - mean)**2) / np.sum(weights))
        

    return means, stdevs

from utils import mean_and_std

# %%
def gauss(x, mean, sigma):
    return np.exp(-(x - mean)**2/(2*sigma**2))

x = np.logspace(0, 2, 100)
print(x[-1])
mean = 50
sigma = 10
y = gauss(x, mean, sigma)

plt.plot(x, y, '.')

means, stdevs = mean_and_std(x, {'a': y}, multi = False)

print(means, stdevs)


means, stdevs = weighted_avg_and_std(x, {'a': y}, multi = False)

print(means, stdevs)
# Out:
# 100.0
# {'a': np.float64(50.000003194073855)} {'a': np.float64(9.999888466812703)}
# {'a': np.float64(47.7908165024334)} {'a': np.float64(10.275196753025599)}
